# %% [markdown]
# # **Preparing Analysis Enviroment - Extract Transform & Load - ETL**

# %% [markdown]
# > **Fetching Data from Kaggle "Data Extraction"**

# %%
# Installing Dependencies to access kaggle resources.
# !pip install kagglehub

# %%
# Initiallizing Kaggle Library
import kagglehub

# Download latest version of the RSNA Bone Age
path = kagglehub.dataset_download("kmader/rsna-bone-age")
print("Path to dataset files:", path)
# Out:
# ...
# 100%|██████████| 9.29G/9.29G [01:40<00:00, 99.5MB/s]
# Extracting files...
# Path to dataset files: /root/.cache/kagglehub/datasets/kmader/rsna-bone-age/versions/2

# %% [markdown]
# > **Verification and "Transformation"**

# %%
# Initiallizing Operating System support libraries for managing files and folders
import os

# Setting cache as default directory
os.chdir('/root/.cache/kagglehub/datasets/kmader/rsna-bone-age/versions/2')
os.getcwd()
# Out:
# '/root/.cache/kagglehub/datasets/kmader/rsna-bone-age/versions/2'

# %%
# List directory contents
os.listdir()
# Out:
# ['boneage-test-dataset',
#  'boneage-training-dataset.csv',
#  'boneage-training-dataset',
#  'boneage-test-dataset.csv']

# %%
# innitializing pandas Library
import pandas as pd

# Using error control method coping file if not found.
try:
  pd = pd.read_csv('boneage-training-dataset.csv')
  pd.to_csv('/content/gdrive/MyDrive/BSBI/BigDataAnalytics/Kaggle/boneage-training-dataset.csv')
  print("File copied to GoogleDrive")
except:
  print("File does not have data (Empty)")
# Out:
# File copied to GoogleDrive

# %%
# Using error control method coping file if not found.
try:
  pd = pd.read_csv('boneage-test-dataset.csv')
  pd.to_csv('/content/gdrive/MyDrive/BSBI/BigDataAnalytics/Kaggle/boneage-test-dataset.csv')
  print("File copied to GoogleDrive")
except:
  print("File does not have data (Empty)")
# Out:
# File does not have data (Empty)

# %%
os.chdir('/root/.cache/kagglehub/datasets/kmader/rsna-bone-age/versions/2/boneage-training-dataset/boneage-training-dataset')
os.getcwd()
# Out:
# '/root/.cache/kagglehub/datasets/kmader/rsna-bone-age/versions/2/boneage-training-dataset/boneage-training-dataset'

# %%
os.listdir()
# Out:
# ['5929.png',
#  '11210.png',
#  '12704.png',
#  '8842.png',
#  '3872.png',
#  '3233.png',
#  '6547.png',
#  '15579.png',
#  '10192.png',
#  '3268.png',
#  '12414.png',
#  '4646.png',
#  '4678.png',
#  '10932.png',
#  '8759.png',
#  '10155.png',
#  '6576.png',
#  '9113.png',
#  '11491.png',
#  '4212.png',
#  '14063.png',
#  '9287.png',
#  '1578.png',
#  '5999.png',
#  '5542.png',
#  '3287.png',
#  '14029.png',
#  '12349.png',
#  '4702.png',
#  '14877.png',
#  '11071.png',
#  '9156.png',
#  '1599.png',
#  '2222.png',
#  '1398.png',
#  '9402.png',
#  '7877.png',
#  '6727.png',
#  '6972.png',
#  '2541.png',
#  '11807.png',
#  '7642.png',
#  '4633.png',
#  '14760.png',
#  '10876.png',
#  '2310.png',
#  '14717.png',
#  '5245.png',
#  '15322.png',
#  '9823.png',
#  '4254.png',
#  '6107.png',
#  '12323.png',
#  '9888.png',
#  '15321.png',
#  '8419.png',
#  '4971.png',
#  '12489.png',
#  '8908.png',
#  '3124.png',
#  '2038.png',
#  '13433.png',
#  '12156.png',
#  '5696.png',
#  '8969.png',
# ...

# %%
# Using Shell Commend to copy "boneage-training-dataset" images to GooglDrive
# !cp -r /root/.cache/kagglehub/datasets/kmader/rsna-bone-age/versions/2/boneage-training-dataset/boneage-training-dataset /content/gdrive/MyDrive/BSBI/BigDataAnalytics/Kaggle

# %% [markdown]
# > **Load and Prepare Data for Analysis**
